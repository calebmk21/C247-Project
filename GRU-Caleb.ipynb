# %% [markdown]
# ## Training Step
# Currently: 1 GRU - CNN - 1 GRU no linear after GRU

# %%
# Single-user training
# !python -m emg2qwerty.train_torch210 \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1 \
  #--multirun
# Out:
# [2026-03-06 16:04:06,703][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ## Training Again

# %%
# Single-user training
# !python -m emg2qwerty.train_torch210 \
  user = "single_user" \
  trainer.accelerator = gpu trainer.devices = 1 \
  #--multirun
# Out:
# Error parsing override 'user'
# missing EQUAL at '<EOF>'
# See https://hydra.cc/docs/1.2/advanced/override_grammar/basic for details
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.

# %% [markdown]
# ## Testing Step
# Don't forget to replace checkpoint
# 'best_checkpoint': '/home/caleb/C247/C247-Project/logs/2026-03-05/20-50-00/checkpoints/epoch=38-step=4680.ckpt'}

# %%
# !python -m emg2qwerty.train_torch210 \
    user="single_user" \
    checkpoint="logs/2026-03-05/12-07-55/checkpoints/epoch\\=38-step\\=4680.ckpt" \
    train=False \
    trainer.accelerator=gpu \
    decoder=ctc_greedy \
    hydra.launcher.mem_gb=64 \

    # --multirun
# Out:
# [2026-03-05 13:27:00,986][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...
